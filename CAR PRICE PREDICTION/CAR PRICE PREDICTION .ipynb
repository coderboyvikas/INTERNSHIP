# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import selenium 
from selenium import webdriver

# %%
driver = webdriver.Chrome(r"C:\web driver\chromedriver.exe")
driver.get("https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001")

# %%
brand_name=[]
variant_name=[]
kmdriven=[]
fuel=[]
number_of_owners=[]
location=[]
price=[]
 
import time 
time.sleep(10)

# %%
brand_names=driver.find_elements_by_xpath("//h2[@class='_3FpCg']")
brand_names[0:569]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="78cd7eac-bb0e-48c9-9f10-75460f8cea73")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="8db1bf20-e375-4bfd-92aa-326314bb02d3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="290d1ac7-ff73-415e-a004-5ffdc6e3e8a6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="0d139851-4c50-4f63-bddb-211a6e909664")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="2719a620-48ec-456e-88df-8f840a88c663")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="78f93fe7-cc95-482a-9663-f17c6a4af661")>,
# ...

# %%
for i in brand_names:
    brand=i.text
    brand_name.append(brand)
brand_name[0:569]
# Out:
# ['2019 Hyundai Verna',
#  '2014 Mercedes Benz C Class',
#  '2020 KIA SELTOS',
#  '2013 Hyundai Grand i10',
#  '2020 KIA SELTOS',
#  '2021 MG HECTOR PLUS',
#  '2021 Renault Kiger',
#  '2019 KIA SELTOS',
#  '2014 Honda City',
#  '2019 KIA SELTOS',
#  '2020 Maruti Baleno',
#  '2013 Jaguar XF',
#  '2017 Honda WR-V',
#  '2014 Honda City',
#  '2021 Tata ALTROZ',
#  '2022 Nissan MAGNITE',
#  '2020 KIA SELTOS',
#  '2014 Hyundai i10',
#  '2020 MG HECTOR PLUS',
#  '2016 Hyundai Grand i10',
#  '2022 Honda Amaze',
#  '2013 Hyundai Grand i10',
#  '2017 Maruti Baleno',
#  '2021 Tata Harrier',
#  '2019 Maruti Baleno',
#  '2018 Ford Figo Aspire',
#  '2010 Honda City',
#  '2020 Hyundai Creta',
#  '2009 Hyundai i20',
#  '2020 Honda City',
#  '2020 KIA SONET',
#  '2020 MG HECTOR PLUS',
#  '2021 Toyota URBAN CRUISER',
#  '2018 Honda Jazz',
#  '2020 Maruti Baleno',
#  '2019 Jeep Compass',
#  '2018 Maruti Dzire',
#  '2018 Hyundai Verna',
#  '2016 Maruti Baleno',
#  '2019 KIA SELTOS',
#  '2019 MG HECTOR',
# ...

# %%
variant_names=driver.find_elements_by_xpath("//p[@class='cvakB']")
variant_names[0:569]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="feb345a9-8572-4733-a4ed-67a2f4fbfa6d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="691d2abe-76bd-49d6-bef1-44d70248ac1f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="4446d236-6a92-4305-a74c-7390c16775b7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="1224b7f3-9c4f-471c-b48e-b31942dc6637")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="168c4291-3fbf-4af9-aa48-8634064273a7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="c0d1d886-d30b-4b6d-b689-0d3e4c344fd5")>,
# ...

# %%
for i in variant_names:
    variant=i.text
    variant_name.append(variant)
variant_name[0:569]
# Out:
# ['1.6 SX VTVT (O) Manual',
#  'C 200 AVANTGARDE Automatic',
#  'GTX + AT PETROL Automatic',
#  'SPORTZ 1.2 KAPPA VTVT Manual',
#  'HTX 1.5 PETROL MT Manual',
#  'SHARP HYBRID PETROL Manual',
#  'RXZ 1.0 MT DUAL TONE',
#  'GTX + AT PETROL Automatic',
#  'VX MT PETROL Manual',
#  'HTK PLUS 1.5 DIESEL Manual',
#  'SIGMA 1.2 K12 Manual',
#  '2.2 DIESEL Automatic',
#  '1.2 i-VTEC VX MT Manual',
#  'SV MT PETROL Manual',
#  'XE 1.2 Manual',
#  'XL Turbo MT',
#  'HTK 1.5 PETROL Manual',
#  'MAGNA 1.1 IRDE2 Manual',
#  'SHARP DCT',
#  'SPORTZ 1.2 KAPPA VTVT Manual',
#  '1.2 VXMT I VTEC Manual',
#  'SPORTZ 1.2 KAPPA VTVT Manual',
#  'SIGMA 1.2 K12 Manual',
#  'XZA DUAL TONE Automatic',
#  'DELTA 1.2 K12 Manual',
#  '1.2 TITANIUM PETROL Manual',
#  'S MT PETROL Manual',
#  'S CRDI Manual',
#  'ASTA 1.2 Manual',
#  'VX MT PETROL Manual',
#  'GTX PLUS DCT 1.0',
#  'SHARP DCT',
#  'PREMIUM MT',
#  '1.2 V AT Automatic',
#  'DELTA 1.2 K12 Manual',
#  '1.4 SPORT PETROL Manual',
#  'LXI Manual',
# ...

# %%
kmdrivens=driver.find_elements_by_xpath("//ul[contains(@class,'bVR0c')]/li[1]")
kmdrivens[0:569]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="432101e2-d1ed-4ee6-9f12-12dab3caa92a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="93181174-e944-4b26-90fb-e5f401e4cf2d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="568ddc52-ca32-4349-88af-7443b961c0a0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="5ffa9c62-02ed-4276-b566-ff0d6fa18a32")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="05746142-3c8a-4a80-bc9d-4051fde6b005")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="e1059164-4935-425f-850f-fa722c0c9cb0")>,
# ...

# %%
for i in kmdrivens:
    km=i.text
    kmdriven.append(km)
kmdriven[0:569]
# Out:
# ['81,902 km',
#  '37,531 km',
#  '8,241 km',
#  '10,558 km',
#  '32,799 km',
#  '3,587 km',
#  '14,474 km',
#  '37,357 km',
#  '61,168 km',
#  '25,067 km',
#  '9,298 km',
#  '28,909 km',
#  '17,511 km',
#  '20,567 km',
#  '7,472 km',
#  '5,306 km',
#  '32,873 km',
#  '41,439 km',
#  '3,483 km',
#  '19,575 km',
#  '3,031 km',
#  '10,558 km',
#  '23,514 km',
#  '16,826 km',
#  '25,647 km',
#  '33,815 km',
#  '39,565 km',
#  '15,734 km',
#  '43,707 km',
#  '6,873 km',
#  '19,496 km',
#  '3,483 km',
#  '18,042 km',
#  '30,916 km',
#  '36,411 km',
#  '42,490 km',
#  '28,929 km',
#  '15,411 km',
#  '22,535 km',
#  '37,357 km',
#  '9,378 km',
#  '2,863 km',
#  '39,565 km',
#  '30,354 km',
#  '43,748 km',
#  '8,964 km',
#  '7,632 km',
#  '12,418 km',
#  '51,321 km',
#  '18,042 km',
#  '7,733 km',
#  '71,180 km',
#  '15,263 km',
#  '27,411 km',
#  '38,725 km',
#  '38,231 km',
#  '10,835 km',
#  '64,587 km',
#  '31,486 km',
#  '72,575 km',
#  '28,496 km',
#  '12,194 km',
#  '6,873 km',
# ...

# %%
fuels=driver.find_elements_by_xpath("//ul[contains(@class,'bVR0c')]/li[3]")
fuels[0:569]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="00f3e2de-e50a-4112-935c-962192444bb3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="aa0235b7-36d0-47d9-bc46-49595bff991d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="246df23e-a1ea-48d1-8cf6-63ad2de20f8f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="5630ad8b-9dd4-4c69-9117-00b52d66f6d6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="adfd3fe5-61c8-486d-9744-f2c46195e201")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="03ee490c-6ad6-4f62-90dc-6c4b63c590cd")>,
# ...

# %%
for i in fuels:
    f=i.text
    fuel.append(f)
fuel[0:569]
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
# ...

# %%
number_of_owner=driver.find_elements_by_xpath("//ul[contains(@class,'bVR0c')]/li[2]")
number_of_owner[0:569]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="3b87da67-1145-4831-83f7-a0dadc3e9077")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="a5ca223a-fabb-4db5-a634-6ebd3f7ee1f5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="bf68627a-2f9c-4279-b625-6be78371a0e2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="b718b815-3bce-4b6b-a5de-6f18198f2362")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="21c4f933-cbc1-49d6-8c0e-919e2c0b89fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="7aa3642f-3500-4725-9996-0347caa6effc")>,
# ...

# %%
for i in number_of_owner:
    owner=i.text
    number_of_owners.append(owner)
number_of_owners[0:569]
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
# ...

# %%
locations=driver.find_elements_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p")
locations[0:569]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="2ef0c264-2cb2-4b81-8a29-bc86785e300c")>]

# %%
for i in locations:
    l=i.text
    location.append(l)
location[0:569]
# Out:
# ['New Delhi']

# %%
prices=driver.find_elements_by_xpath("//div[contains(@class,'_7udZZ')]/span[1]")
prices[0:569]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="5ab18e70-32a9-4873-8b54-d45503fc0210")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="763d7919-c911-42ce-b76f-98a51f8660e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="4102bd70-c99c-47db-a548-5d29836a022b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="5ceaf128-e9fe-4f25-85dc-b63d478a2ee8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="a83505a7-5c1f-4652-b4d4-7fd0fdb23088")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="8f42d26f-9321-45af-96ea-8861055fdb12")>,
# ...

# %%
for i in prices:
    p=i.text
    price.append(p)
price[0:569]
# Out:
# ['₹9,81,699',
#  '₹20,53,699',
#  '₹19,06,399',
#  '₹4,00,099',
#  '₹13,75,499',
#  '₹18,19,949',
#  '₹8,23,199',
#  '₹16,79,499',
#  '₹6,59,699',
#  '₹13,07,499',
#  '₹6,03,599',
#  '₹15,49,999',
#  '₹7,79,899',
#  '₹6,05,299',
#  '₹6,41,999',
#  '₹8,54,599',
#  '₹12,26,699',
#  '₹3,49,399',
#  '₹19,44,099',
#  '₹5,01,099',
#  '₹9,45,599',
#  '₹4,00,099',
#  '₹5,23,999',
#  '₹21,11,249',
#  '₹6,80,999',
#  '₹5,76,999',
#  '₹4,02,699',
#  '₹14,50,499',
#  '₹2,31,049',
#  '₹13,04,899',
#  '₹13,72,399',
#  '₹19,44,099',
#  '₹10,34,599',
#  '₹6,96,299',
#  '₹7,11,199',
#  '₹13,89,799',
#  '₹5,42,299',
#  '₹11,20,599',
#  '₹5,78,099',
#  '₹16,79,499',
#  '₹17,94,899',
#  '₹4,73,299',
#  '₹4,02,699',
#  '₹3,06,299',
#  '₹6,46,799',
#  '₹7,81,399',
#  '₹12,97,699',
#  '₹6,08,599',
#  '₹4,41,899',
#  '₹10,34,599',
#  '₹9,06,699',
#  '₹11,24,299',
#  '₹8,34,099',
#  '₹3,28,049',
#  '₹3,85,099',
#  '₹3,19,399',
#  '₹9,61,599',
#  '₹2,90,899',
#  '₹3,50,699',
#  '₹12,04,299',
#  '₹6,57,799',
# ...

# %%
len(variant_name)
# Out:
# 559

# %%
df = pd.DataFrame({})
df['BRAND']=brand_name
df['VARIANT']=variant_name
df['KILOMETER']=kmdriven
df['TYPE_OF_FUEL']=fuel
df['OWNER']=number_of_owners
df['PRICE']=price
df
# Out:
#                           BRAND                             VARIANT  \
# 0            2019 Hyundai Verna              1.6 SX VTVT (O) Manual
# 1    2014 Mercedes Benz C Class          C 200 AVANTGARDE Automatic
# 2               2020 KIA SELTOS           GTX + AT PETROL Automatic
# 3        2013 Hyundai Grand i10        SPORTZ 1.2 KAPPA VTVT Manual
# 4               2020 KIA SELTOS            HTX 1.5 PETROL MT Manual
# ..                          ...                                 ...
# 554     2018 Maruti Wagon R 1.0                          LXI Manual
# 555           2017 Maruti Swift                      LXI OPT Manual
# 556           2019 Renault Kwid  RXT 1.0 EASY-R AT OPTION Automatic
# 557     2019 Hyundai NEW SANTRO                  ASTA 1.1 MT Manual
# 558           2020 Renault Kwid                  1.0 RXT Opt Manual
#
#      KILOMETER TYPE_OF_FUEL      OWNER       PRICE
# 0    81,902 km       Petrol  1st Owner   ₹9,81,699
# ...

# %%
select_city1=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p")
select_city1.click()

# %%
noida_city=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div/div[2]/ul/li[2]/a/span/img")
noida_city.click()

# %%
brand_names=driver.find_elements_by_xpath("//h2[@class='_3FpCg']")
brand_names[0:570]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="57ba0f9c-33ac-4d32-bb77-676a6e7f0d23")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="1c70aef2-ea58-4c68-ab99-5ce8acad3d77")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="d30c5e7f-a573-434b-b543-deb86f9b48d6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="69bd1414-d30a-44b5-8bc5-23ac380c36e5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="dc92ac70-970d-4002-b528-7f0b66c9d403")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="f6f17e90-df09-4284-b00e-6d80e043f4f5")>,
# ...

# %%
len(brand_name)
# Out:
# 559

# %%
for i in brand_names:
    brand=i.text
    brand_name.append(brand)
brand_name[0:1140]
# Out:
# ['2019 Hyundai Verna',
#  '2014 Mercedes Benz C Class',
#  '2020 KIA SELTOS',
#  '2013 Hyundai Grand i10',
#  '2020 KIA SELTOS',
#  '2021 MG HECTOR PLUS',
#  '2021 Renault Kiger',
#  '2019 KIA SELTOS',
#  '2014 Honda City',
#  '2019 KIA SELTOS',
#  '2020 Maruti Baleno',
#  '2013 Jaguar XF',
#  '2017 Honda WR-V',
#  '2014 Honda City',
#  '2021 Tata ALTROZ',
#  '2022 Nissan MAGNITE',
#  '2020 KIA SELTOS',
#  '2014 Hyundai i10',
#  '2020 MG HECTOR PLUS',
#  '2016 Hyundai Grand i10',
#  '2022 Honda Amaze',
#  '2013 Hyundai Grand i10',
#  '2017 Maruti Baleno',
#  '2021 Tata Harrier',
#  '2019 Maruti Baleno',
#  '2018 Ford Figo Aspire',
#  '2010 Honda City',
#  '2020 Hyundai Creta',
#  '2009 Hyundai i20',
#  '2020 Honda City',
#  '2020 KIA SONET',
#  '2020 MG HECTOR PLUS',
#  '2021 Toyota URBAN CRUISER',
#  '2018 Honda Jazz',
#  '2020 Maruti Baleno',
#  '2019 Jeep Compass',
#  '2018 Maruti Dzire',
#  '2018 Hyundai Verna',
#  '2016 Maruti Baleno',
#  '2019 KIA SELTOS',
#  '2019 MG HECTOR',
# ...

# %%
len(brand_name)
# Out:
# 1118

# %%
variant_names=driver.find_elements_by_xpath("//p[@class='cvakB']")
variant_names[0:570]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="c281aa57-79e5-44b7-8ce3-87af2319e5f6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="16da68cd-7e6a-4073-a1bd-c98055216c6b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="85b3d841-97f7-4bf3-87b6-f93832d71c46")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="4f51909a-ad59-44fe-9685-60d1c28fb148")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="6f9bae1e-99bc-4b0c-8ebd-2e07de572b5b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="cbe08811-b1d6-4e38-88c0-0a90fb275244")>,
# ...

# %%
 for i in variant_names:
    variant=i.text
    variant_name.append(variant)
variant_name[0:1140]
# Out:
# ['1.6 SX VTVT (O) Manual',
#  'C 200 AVANTGARDE Automatic',
#  'GTX + AT PETROL Automatic',
#  'SPORTZ 1.2 KAPPA VTVT Manual',
#  'HTX 1.5 PETROL MT Manual',
#  'SHARP HYBRID PETROL Manual',
#  'RXZ 1.0 MT DUAL TONE',
#  'GTX + AT PETROL Automatic',
#  'VX MT PETROL Manual',
#  'HTK PLUS 1.5 DIESEL Manual',
#  'SIGMA 1.2 K12 Manual',
#  '2.2 DIESEL Automatic',
#  '1.2 i-VTEC VX MT Manual',
#  'SV MT PETROL Manual',
#  'XE 1.2 Manual',
#  'XL Turbo MT',
#  'HTK 1.5 PETROL Manual',
#  'MAGNA 1.1 IRDE2 Manual',
#  'SHARP DCT',
#  'SPORTZ 1.2 KAPPA VTVT Manual',
#  '1.2 VXMT I VTEC Manual',
#  'SPORTZ 1.2 KAPPA VTVT Manual',
#  'SIGMA 1.2 K12 Manual',
#  'XZA DUAL TONE Automatic',
#  'DELTA 1.2 K12 Manual',
#  '1.2 TITANIUM PETROL Manual',
#  'S MT PETROL Manual',
#  'S CRDI Manual',
#  'ASTA 1.2 Manual',
#  'VX MT PETROL Manual',
#  'GTX PLUS DCT 1.0',
#  'SHARP DCT',
#  'PREMIUM MT',
#  '1.2 V AT Automatic',
#  'DELTA 1.2 K12 Manual',
#  '1.4 SPORT PETROL Manual',
#  'LXI Manual',
# ...

# %%
len(variant_name)
# Out:
# 1118

# %%
kmdrivens=driver.find_elements_by_xpath("//ul[contains(@class,'bVR0c')]/li[1]")
kmdrivens[0:570]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="bc113ae4-7cbc-451a-b354-d27c7204e1a3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="53b172b0-8211-45c6-a326-c9dfa805f94f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="b060eb23-fb1e-4cf5-b5a4-502be46260e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="c01c04ac-0836-4c5e-b309-4461844ccadf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="f1d1534b-6986-4dca-9215-42cccf39f26f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="ab9da4cd-4041-45ab-9389-6f306ba1a601")>,
# ...

# %%
for i in kmdrivens:
    km=i.text
    kmdriven.append(km)
kmdriven[0:1140]
# Out:
# ['81,902 km',
#  '37,531 km',
#  '8,241 km',
#  '10,558 km',
#  '32,799 km',
#  '3,587 km',
#  '14,474 km',
#  '37,357 km',
#  '61,168 km',
#  '25,067 km',
#  '9,298 km',
#  '28,909 km',
#  '17,511 km',
#  '20,567 km',
#  '7,472 km',
#  '5,306 km',
#  '32,873 km',
#  '41,439 km',
#  '3,483 km',
#  '19,575 km',
#  '3,031 km',
#  '10,558 km',
#  '23,514 km',
#  '16,826 km',
#  '25,647 km',
#  '33,815 km',
#  '39,565 km',
#  '15,734 km',
#  '43,707 km',
#  '6,873 km',
#  '19,496 km',
#  '3,483 km',
#  '18,042 km',
#  '30,916 km',
#  '36,411 km',
#  '42,490 km',
#  '28,929 km',
#  '15,411 km',
#  '22,535 km',
#  '37,357 km',
#  '9,378 km',
#  '2,863 km',
#  '39,565 km',
#  '30,354 km',
#  '43,748 km',
#  '8,964 km',
#  '7,632 km',
#  '12,418 km',
#  '51,321 km',
#  '18,042 km',
#  '7,733 km',
#  '71,180 km',
#  '15,263 km',
#  '27,411 km',
#  '38,725 km',
#  '38,231 km',
#  '10,835 km',
#  '64,587 km',
#  '31,486 km',
#  '72,575 km',
#  '28,496 km',
#  '12,194 km',
#  '6,873 km',
# ...

# %%
fuels=driver.find_elements_by_xpath("//ul[contains(@class,'bVR0c')]/li[3]")
fuels[0:570]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="9a9434c9-a3c0-4155-b74f-b0c4c8467db5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="4caa5a5a-040c-483a-a682-32082603edb6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="5029ffc7-9d8a-492f-9d01-4b9a73ec2005")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="1975048d-85b9-4ce3-9bc0-13cfaecae85c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="7387ad30-f5f0-4e3c-ad9d-87bec7d987a2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="143908ce-5e3a-480d-9af0-82bd595f74e5")>,
# ...

# %%
for i in fuels:
    f=i.text
    fuel.append(f)
fuel[0:1140]
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
# ...

# %%
number_of_owner=driver.find_elements_by_xpath("//ul[contains(@class,'bVR0c')]/li[2]")
number_of_owner[0:570]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="385148c1-361f-4734-9079-7b84628b3865")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="6c4eafd3-9810-407d-88b9-64bc149024d1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="cd1e60e4-8f7d-4b50-9ecf-5e2f20a1bed9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="93a8d6f1-856f-4c22-a4ca-3d20383cf381")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="a1e4030c-6e85-461a-9c43-0537a5f2127b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="55a0282b-08bb-4c53-8964-8357f514e26d")>,
# ...

# %%
for i in number_of_owner:
    owner=i.text
    number_of_owners.append(owner)
number_of_owners[0:1140]
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
# ...

# %%
prices=driver.find_elements_by_xpath("//div[contains(@class,'_7udZZ')]/span[1]")
prices[0:570]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="8f2e4417-f08c-44f3-806a-e86a7ab93644")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="1d148731-1676-491b-a830-19beeaf6964e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="881860d5-6b7d-4ea0-bd1d-a9d5b15fd7ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="f5311c09-e10b-45a9-880c-c703cacd15a9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="691f4eb1-3c86-435f-8b0a-2e9d2a8e9b93")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="5d99d8cd-922a-4a5b-8c1d-23218676c4c5")>,
# ...

# %%
for i in prices:
    p=i.text
    price.append(p)
price[0:1140]
# Out:
# ['₹9,81,699',
#  '₹20,53,699',
#  '₹19,06,399',
#  '₹4,00,099',
#  '₹13,75,499',
#  '₹18,19,949',
#  '₹8,23,199',
#  '₹16,79,499',
#  '₹6,59,699',
#  '₹13,07,499',
#  '₹6,03,599',
#  '₹15,49,999',
#  '₹7,79,899',
#  '₹6,05,299',
#  '₹6,41,999',
#  '₹8,54,599',
#  '₹12,26,699',
#  '₹3,49,399',
#  '₹19,44,099',
#  '₹5,01,099',
#  '₹9,45,599',
#  '₹4,00,099',
#  '₹5,23,999',
#  '₹21,11,249',
#  '₹6,80,999',
#  '₹5,76,999',
#  '₹4,02,699',
#  '₹14,50,499',
#  '₹2,31,049',
#  '₹13,04,899',
#  '₹13,72,399',
#  '₹19,44,099',
#  '₹10,34,599',
#  '₹6,96,299',
#  '₹7,11,199',
#  '₹13,89,799',
#  '₹5,42,299',
#  '₹11,20,599',
#  '₹5,78,099',
#  '₹16,79,499',
#  '₹17,94,899',
#  '₹4,73,299',
#  '₹4,02,699',
#  '₹3,06,299',
#  '₹6,46,799',
#  '₹7,81,399',
#  '₹12,97,699',
#  '₹6,08,599',
#  '₹4,41,899',
#  '₹10,34,599',
#  '₹9,06,699',
#  '₹11,24,299',
#  '₹8,34,099',
#  '₹3,28,049',
#  '₹3,85,099',
#  '₹3,19,399',
#  '₹9,61,599',
#  '₹2,90,899',
#  '₹3,50,699',
#  '₹12,04,299',
#  '₹6,57,799',
# ...

# %%
len(price)
# Out:
# 1118

# %%
df = pd.DataFrame({})
df['BRAND']=brand_name[0:1138]
df['VARIANT']=variant_name
df['KILOMETER']=kmdriven
df['TYPE_OF_FUEL']=fuel
df['OWNER']=number_of_owners
df['PRICE']=price
df
# Out:
#                            BRAND                             VARIANT  \
# 0             2019 Hyundai Verna              1.6 SX VTVT (O) Manual
# 1     2014 Mercedes Benz C Class          C 200 AVANTGARDE Automatic
# 2                2020 KIA SELTOS           GTX + AT PETROL Automatic
# 3         2013 Hyundai Grand i10        SPORTZ 1.2 KAPPA VTVT Manual
# 4                2020 KIA SELTOS            HTX 1.5 PETROL MT Manual
# ...                          ...                                 ...
# 1113     2018 Maruti Wagon R 1.0                          LXI Manual
# 1114           2017 Maruti Swift                      LXI OPT Manual
# 1115           2019 Renault Kwid  RXT 1.0 EASY-R AT OPTION Automatic
# 1116     2019 Hyundai NEW SANTRO                  ASTA 1.1 MT Manual
# 1117           2020 Renault Kwid                  1.0 RXT Opt Manual
#
#       KILOMETER TYPE_OF_FUEL      OWNER       PRICE
# 0     81,902 km       Petrol  1st Owner   ₹9,81,699
# ...

# %%
select_city2=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p").click()

# %%
gurgaon_city=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div/div[2]/ul/li[3]/a/span/img").click()

# %%
brand_names=driver.find_elements_by_xpath("//h2[@class='_3FpCg']")
brand_names[0:570]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="ee5cca30-68c3-4f30-8597-21b2dff068eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="2bcbaeda-c469-4356-865d-fa2015756f3d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="da7c08be-0469-48cf-92fb-c26491d08520")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="9841561b-e79e-43fa-ba6a-0f5d5d1bb7bf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="f1396d06-5c80-47b9-913a-a39c200d2868")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="2218d8b8-b34c-4e24-b0a3-02db3d346277")>,
# ...

# %%
for i in brand_names:
    brand=i.text
    brand_name.append(brand)
brand_name[0:1710]
# Out:
# ['2019 Hyundai Verna',
#  '2014 Mercedes Benz C Class',
#  '2020 KIA SELTOS',
#  '2013 Hyundai Grand i10',
#  '2020 KIA SELTOS',
#  '2021 MG HECTOR PLUS',
#  '2021 Renault Kiger',
#  '2019 KIA SELTOS',
#  '2014 Honda City',
#  '2019 KIA SELTOS',
#  '2020 Maruti Baleno',
#  '2013 Jaguar XF',
#  '2017 Honda WR-V',
#  '2014 Honda City',
#  '2021 Tata ALTROZ',
#  '2022 Nissan MAGNITE',
#  '2020 KIA SELTOS',
#  '2014 Hyundai i10',
#  '2020 MG HECTOR PLUS',
#  '2016 Hyundai Grand i10',
#  '2022 Honda Amaze',
#  '2013 Hyundai Grand i10',
#  '2017 Maruti Baleno',
#  '2021 Tata Harrier',
#  '2019 Maruti Baleno',
#  '2018 Ford Figo Aspire',
#  '2010 Honda City',
#  '2020 Hyundai Creta',
#  '2009 Hyundai i20',
#  '2020 Honda City',
#  '2020 KIA SONET',
#  '2020 MG HECTOR PLUS',
#  '2021 Toyota URBAN CRUISER',
#  '2018 Honda Jazz',
#  '2020 Maruti Baleno',
#  '2019 Jeep Compass',
#  '2018 Maruti Dzire',
#  '2018 Hyundai Verna',
#  '2016 Maruti Baleno',
#  '2019 KIA SELTOS',
#  '2019 MG HECTOR',
# ...

# %%
len(brand_name)
# Out:
# 1676

# %%
variant_names=driver.find_elements_by_xpath("//p[@class='cvakB']")
variant_names[0:570]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="58807871-a1f0-439c-8fe6-bf114419ba58")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="431c7179-d5df-4435-88ea-70591dc919bb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="f0d5571d-259b-4b95-ad04-22d8dbebdc0e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="4202e74a-67ab-44d6-a91f-a4271f1c29ca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="769178d2-2e9b-4133-9a0e-f9e09e9a8c32")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="d90ff1e2-e517-4aa1-848c-854e2c740aa6")>,
# ...

# %%
for i in variant_names:
    variant=i.text
    variant_name.append(variant)
variant_name[0:1710]
# Out:
# ['1.6 SX VTVT (O) Manual',
#  'C 200 AVANTGARDE Automatic',
#  'GTX + AT PETROL Automatic',
#  'SPORTZ 1.2 KAPPA VTVT Manual',
#  'HTX 1.5 PETROL MT Manual',
#  'SHARP HYBRID PETROL Manual',
#  'RXZ 1.0 MT DUAL TONE',
#  'GTX + AT PETROL Automatic',
#  'VX MT PETROL Manual',
#  'HTK PLUS 1.5 DIESEL Manual',
#  'SIGMA 1.2 K12 Manual',
#  '2.2 DIESEL Automatic',
#  '1.2 i-VTEC VX MT Manual',
#  'SV MT PETROL Manual',
#  'XE 1.2 Manual',
#  'XL Turbo MT',
#  'HTK 1.5 PETROL Manual',
#  'MAGNA 1.1 IRDE2 Manual',
#  'SHARP DCT',
#  'SPORTZ 1.2 KAPPA VTVT Manual',
#  '1.2 VXMT I VTEC Manual',
#  'SPORTZ 1.2 KAPPA VTVT Manual',
#  'SIGMA 1.2 K12 Manual',
#  'XZA DUAL TONE Automatic',
#  'DELTA 1.2 K12 Manual',
#  '1.2 TITANIUM PETROL Manual',
#  'S MT PETROL Manual',
#  'S CRDI Manual',
#  'ASTA 1.2 Manual',
#  'VX MT PETROL Manual',
#  'GTX PLUS DCT 1.0',
#  'SHARP DCT',
#  'PREMIUM MT',
#  '1.2 V AT Automatic',
#  'DELTA 1.2 K12 Manual',
#  '1.4 SPORT PETROL Manual',
#  'LXI Manual',
# ...

# %%
kmdrivens=driver.find_elements_by_xpath("//ul[contains(@class,'bVR0c')]/li[1]")
kmdrivens[0:570]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="e4f9a83f-ae19-43b6-99be-90ef8b9ea37b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="c27e7819-fe53-4b8e-afd1-341f1988c980")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="3bbcf512-68fe-40bd-a149-e485fcbd151b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="716e3570-3afa-474a-8558-20abf91fe658")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="54ca11d3-2c43-47c3-ac2c-9c04f8e8b16c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="b5876137-0e5f-4695-8e72-7199538001d5")>,
# ...

# %%
for i in kmdrivens:
    km=i.text
    kmdriven.append(km)
kmdriven[0:1710]
# Out:
# ['81,902 km',
#  '37,531 km',
#  '8,241 km',
#  '10,558 km',
#  '32,799 km',
#  '3,587 km',
#  '14,474 km',
#  '37,357 km',
#  '61,168 km',
#  '25,067 km',
#  '9,298 km',
#  '28,909 km',
#  '17,511 km',
#  '20,567 km',
#  '7,472 km',
#  '5,306 km',
#  '32,873 km',
#  '41,439 km',
#  '3,483 km',
#  '19,575 km',
#  '3,031 km',
#  '10,558 km',
#  '23,514 km',
#  '16,826 km',
#  '25,647 km',
#  '33,815 km',
#  '39,565 km',
#  '15,734 km',
#  '43,707 km',
#  '6,873 km',
#  '19,496 km',
#  '3,483 km',
#  '18,042 km',
#  '30,916 km',
#  '36,411 km',
#  '42,490 km',
#  '28,929 km',
#  '15,411 km',
#  '22,535 km',
#  '37,357 km',
#  '9,378 km',
#  '2,863 km',
#  '39,565 km',
#  '30,354 km',
#  '43,748 km',
#  '8,964 km',
#  '7,632 km',
#  '12,418 km',
#  '51,321 km',
#  '18,042 km',
#  '7,733 km',
#  '71,180 km',
#  '15,263 km',
#  '27,411 km',
#  '38,725 km',
#  '38,231 km',
#  '10,835 km',
#  '64,587 km',
#  '31,486 km',
#  '72,575 km',
#  '28,496 km',
#  '12,194 km',
#  '6,873 km',
# ...

# %%
fuels=driver.find_elements_by_xpath("//ul[contains(@class,'bVR0c')]/li[3]")
fuels[0:570]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="7df2f647-aedc-4335-8056-b282a7a71a09")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="87b8ab6c-6ee6-4d54-b30b-c69b12cdec8d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="3fd96fc4-76e0-4d7d-8805-5c8de5dac94e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="67f3eaf3-a0b4-4b1c-be64-03717dfd6421")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="1e7a849f-e81b-4236-8c23-20c0d079cff3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="a79e70f0-17cd-4526-b8d9-bd623c5c77fe")>,
# ...

# %%
for i in fuels:
    f=i.text
    fuel.append(f)
fuel[0:1710]
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
# ...

# %%
number_of_owner=driver.find_elements_by_xpath("//ul[contains(@class,'bVR0c')]/li[2]")
number_of_owner[0:570]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="0d6681cd-1310-4f4c-a9de-02b3584c368b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="f6e84284-3542-4bd1-b808-a8f7efdbbc75")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="f2cd6213-d715-41d7-b2f2-59b124e537f1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="0b5522a4-8e9f-4392-80fe-de90d5ea5f70")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="0a4ea70f-52b3-45b8-9d2a-94f5f6b50386")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="6e8ae134-f72d-4799-ac16-0b7fe6955139")>,
# ...

# %%
for i in number_of_owner:
    owner=i.text
    number_of_owners.append(owner)
number_of_owners[0:1710]
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
# ...

# %%
prices=driver.find_elements_by_xpath("//div[contains(@class,'_7udZZ')]/span[1]")
prices[0:570]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="ab891d82-a534-47e8-a07e-ef998a5c66f6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="77571c98-6e15-4f4f-890d-ed31d80fb13d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="8e1335da-f674-437f-b801-6c3b124200e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="21c79ee2-b3f4-4b05-9576-ffb946fe8c9e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="97986459-619a-473a-80a7-b88847741dce")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="475e99b3a8e7f24b5bd9847af092abfa", element="11ca18a7-6fc1-4a25-8adc-f2022c8217d9")>,
# ...

# %%
for i in prices:
    p=i.text
    price.append(p)
price[0:1710]
# Out:
# ['₹9,81,699',
#  '₹20,53,699',
#  '₹19,06,399',
#  '₹4,00,099',
#  '₹13,75,499',
#  '₹18,19,949',
#  '₹8,23,199',
#  '₹16,79,499',
#  '₹6,59,699',
#  '₹13,07,499',
#  '₹6,03,599',
#  '₹15,49,999',
#  '₹7,79,899',
#  '₹6,05,299',
#  '₹6,41,999',
#  '₹8,54,599',
#  '₹12,26,699',
#  '₹3,49,399',
#  '₹19,44,099',
#  '₹5,01,099',
#  '₹9,45,599',
#  '₹4,00,099',
#  '₹5,23,999',
#  '₹21,11,249',
#  '₹6,80,999',
#  '₹5,76,999',
#  '₹4,02,699',
#  '₹14,50,499',
#  '₹2,31,049',
#  '₹13,04,899',
#  '₹13,72,399',
#  '₹19,44,099',
#  '₹10,34,599',
#  '₹6,96,299',
#  '₹7,11,199',
#  '₹13,89,799',
#  '₹5,42,299',
#  '₹11,20,599',
#  '₹5,78,099',
#  '₹16,79,499',
#  '₹17,94,899',
#  '₹4,73,299',
#  '₹4,02,699',
#  '₹3,06,299',
#  '₹6,46,799',
#  '₹7,81,399',
#  '₹12,97,699',
#  '₹6,08,599',
#  '₹4,41,899',
#  '₹10,34,599',
#  '₹9,06,699',
#  '₹11,24,299',
#  '₹8,34,099',
#  '₹3,28,049',
#  '₹3,85,099',
#  '₹3,19,399',
#  '₹9,61,599',
#  '₹2,90,899',
#  '₹3,50,699',
#  '₹12,04,299',
#  '₹6,57,799',
# ...

# %%
len(price)
# Out:
# 1676

# %%
df = pd.DataFrame({})
df['BRAND']=brand_name[0:1707]
df['VARIANT']=variant_name
df['KILOMETER']=kmdriven
df['TYPE_OF_FUEL']=fuel
df['OWNER']=number_of_owners
df['PRICE']=price
df
# Out:
#                            BRAND                             VARIANT  \
# 0             2019 Hyundai Verna              1.6 SX VTVT (O) Manual
# 1     2014 Mercedes Benz C Class          C 200 AVANTGARDE Automatic
# 2                2020 KIA SELTOS           GTX + AT PETROL Automatic
# 3         2013 Hyundai Grand i10        SPORTZ 1.2 KAPPA VTVT Manual
# 4                2020 KIA SELTOS            HTX 1.5 PETROL MT Manual
# ...                          ...                                 ...
# 1671     2018 Maruti Wagon R 1.0                          LXI Manual
# 1672           2017 Maruti Swift                      LXI OPT Manual
# 1673           2019 Renault Kwid  RXT 1.0 EASY-R AT OPTION Automatic
# 1674     2019 Hyundai NEW SANTRO                  ASTA 1.1 MT Manual
# 1675           2020 Renault Kwid                  1.0 RXT Opt Manual
#
#       KILOMETER TYPE_OF_FUEL      OWNER       PRICE
# 0     81,902 km       Petrol  1st Owner   ₹9,81,699
# ...

# %%
df.head()
# Out:
#                         BRAND                       VARIANT  KILOMETER  \
# 0          2019 Hyundai Verna        1.6 SX VTVT (O) Manual  81,902 km
# 1  2014 Mercedes Benz C Class    C 200 AVANTGARDE Automatic  37,531 km
# 2             2020 KIA SELTOS     GTX + AT PETROL Automatic   8,241 km
# 3      2013 Hyundai Grand i10  SPORTZ 1.2 KAPPA VTVT Manual  10,558 km
# 4             2020 KIA SELTOS      HTX 1.5 PETROL MT Manual  32,799 km
#
#   TYPE_OF_FUEL      OWNER       PRICE
# 0       Petrol  1st Owner   ₹9,81,699
# 1       Petrol  1st Owner  ₹20,53,699
# 2       Petrol  1st Owner  ₹19,06,399
# 3       Petrol  1st Owner   ₹4,00,099
# 4       Petrol  1st Owner  ₹13,75,499

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                             BRAND     VARIANT  KILOMETER TYPE_OF_FUEL  \
# count                        1676        1676       1676         1676
# unique                        235         230        558            3
# top     2016 Maruti Vitara Brezza  VXI Manual  32,873 km       Petrol
# freq                           45         123          6          992
#
#             OWNER      PRICE
# count        1676       1676
# unique          3        542
# top     1st Owner  ₹5,25,199
# freq         1341          9

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['VARIANT']=le.fit_transform(df['VARIANT'])
df['TYPE_OF_FUEL']=le.fit_transform(df['TYPE_OF_FUEL'])
df['BRAND']=le.fit_transform(df['BRAND'])
df['KILOMETER']=le.fit_transform(df['KILOMETER'])
df['OWNER']=le.fit_transform(df['OWNER'])
df['PRICE']=le.fit_transform(df['PRICE'])

# %%
df.head()
# Out:
#    BRAND  VARIANT  KILOMETER  TYPE_OF_FUEL  OWNER  PRICE
# 0    150       49        499             1      0    537
# 1     44       88        230             1      0    114
# 2    180      117        489             1      0     92
# 3     18      166         26             1      0    205
# 4    180      124        193             1      0     59

# %%
df.corr()
# Out:
#                  BRAND   VARIANT  KILOMETER  TYPE_OF_FUEL     OWNER     PRICE
# BRAND         1.000000  0.035404  -0.296660      0.345185 -0.137867  0.161094
# VARIANT       0.035404  1.000000  -0.047831      0.002921  0.016597 -0.043305
# KILOMETER    -0.296660 -0.047831   1.000000     -0.282945  0.008743 -0.022588
# TYPE_OF_FUEL  0.345185  0.002921  -0.282945      1.000000 -0.036084  0.018879
# OWNER        -0.137867  0.016597   0.008743     -0.036084  1.000000 -0.043504
# PRICE         0.161094 -0.043305  -0.022588      0.018879 -0.043504  1.000000

# %%
df.skew()
# Out:
# BRAND           0.079271
# VARIANT        -0.441789
# KILOMETER       0.006307
# TYPE_OF_FUEL   -0.123705
# OWNER           1.681163
# PRICE          -0.006784
# dtype: float64

# %%
x=df.drop('PRICE',axis=1)
y=df['PRICE']
x=df.drop('BRAND',axis=1)

# %%
x
# Out:
#       VARIANT  KILOMETER  TYPE_OF_FUEL  OWNER  PRICE
# 0          49        499             1      0    537
# 1          88        230             1      0    114
# 2         117        489             1      0     92
# 3         166         26             1      0    205
# 4         124        193             1      0     59
# ...       ...        ...           ...    ...    ...
# 1671      133         82             1      0    233
# 1672      134        267             1      0    228
# 1673      144        255             1      0    261
# 1674       83         40             1      0    337
# 1675        2         27             1      1    257
#
# [1676 rows x 5 columns]

# %%
y
# Out:
# 0       537
# 1       114
# 2        92
# 3       205
# 4        59
#        ...
# 1671    233
# 1672    228
# 1673    261
# 1674    337
# 1675    257
# Name: PRICE, Length: 1676, dtype: int32

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5)

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
predict=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,predict)
# Out:
# 1.0
